# %% [markdown]
# IMPORTANDO AS BIBLIOTECAS

# %%
import pandas as pd

# %% [markdown]
# IMPORTANDO A BASE

# %%
df = pd.read_csv('/Users/tuts/Downloads/ProjetoIntegrador/Assignment-1_Data.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df = pd.read_csv('/Users/tuts/Downloads/ProjetoIntegrador/Assignment-1_Data.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# EXPLORANDO A BASE

# %%
df.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522063 entries, 0 to 522062
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522063 non-null  object
#  1   Itemname    520608 non-null  object
#  2   Quantity    522063 non-null  int64
#  3   Date        522063 non-null  object
#  4   Price       522063 non-null  object
#  5   CustomerID  388022 non-null  float64
#  6   Country     522063 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
df.describe()
# Out:
#             Quantity     CustomerID
# count  522063.000000  388022.000000
# mean       10.090451   15316.931726
# std       161.110679    1721.849183
# min     -9600.000000   12346.000000
# 25%         1.000000   13950.000000
# 50%         3.000000   15265.000000
# 75%        10.000000   16837.000000
# max     80995.000000   18287.000000

# %% [markdown]
# VERIFICANDO VALORES NÚLOS E DUPLICADOS

# %%
df.isnull().sum()
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %%
((df.isnull().sum())/len(df))*100
# Out:
# BillNo         0.000000
# Itemname       0.278702
# Quantity       0.000000
# Date           0.000000
# Price          0.000000
# CustomerID    25.675254
# Country        0.000000
# dtype: float64

# %%
df.dropna(subset=['CustomerID'],inplace=True)

# %%
df.dropna(subset=['Itemname'],inplace=True)

# %%
df.duplicated().sum()
# Out:
# 5210

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# TROCANDO SEPARADORES

# %%
df['Price'] = df['Price'].str.replace(',', '.').astype(float)

# %% [markdown]
# CONVERTENDO A DATA

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d.%m.%Y %H:%M')
df['YearMonth'] = df['Date'].dt.to_period('M')

# %%
df.head()
# Out:
#    BillNo                             Itemname  Quantity                Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1  536365                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    Price  CustomerID         Country YearMonth
# 0   2.55     17850.0  United Kingdom   2010-12
# 1   3.39     17850.0  United Kingdom   2010-12
# 2   2.75     17850.0  United Kingdom   2010-12
# 3   3.39     17850.0  United Kingdom   2010-12
# 4   3.39     17850.0  United Kingdom   2010-12

# %% [markdown]
# CRIANDO UMA NOVA BASE

# %%
caminho_arquivo = 'MarketBasket.csv'

df.to_csv(caminho_arquivo, index=False)

print(f"Arquivo CSV '{caminho_arquivo}' criado com sucesso.")
# Out:
# Arquivo CSV 'MarketBasket.csv' criado com sucesso.
